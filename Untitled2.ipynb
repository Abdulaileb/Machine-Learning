# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("canada_per_capita_income.csv")
df.head(5)
# Out:
#    year  per_capita_income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
predicted_Val = reg.predict([[2020]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('per_capita_income (US$)')
plt.scatter(df['year'],df['per_capita_income (US$)'],color='red',marker='+')
plt.show()

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['year']],df[['per_capita_income (US$)']] )
# Out:
# LinearRegression()

# %%
predicted_value = reg.predict(pd.DataFrame([[2020]], columns=['year']))

# %%
reg.predict([[2011]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[33832.50841741]])

# %%
predicted_Val = reg.predict([[2020]])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# %matplotlib inline
plt.xlabel('year', fontsize=20)
plt.ylabel('per_capita_income (US$))', fontsize=20)

plt.scatter(df['year'],df['per_capita_income (US$)'],color='red',marker='+')
plt.plot(df['year'],reg.predict(df[['year']]),color="red")

#Show the prediction for 2020
plt.scatter([2020], predicted_Val, color='green', marker='o', label=f'Prediction for 2020: {predicted_Val[0][0]:.2f}')
plt.length()
plt.show()

#Print prediction for 2020
print(f"The predicted per capita income for the year 2020 is: ${predicted_Val[0][0]:.2f})

# %%
# %matplotlib inline
plt.xlabel('year', fontsize=20)
plt.ylabel('per_capita_income (US$))', fontsize=20)

plt.scatter(df['year'],df['per_capita_income (US$)'],color='red',marker='+')
plt.plot(df['year'],reg.predict(df[['year']]),color="red")

#Show the prediction for 2020
plt.scatter([2020], predicted_Val, color='green', marker='o', label=f'Prediction for 2020: {predicted_Val[0][0]:.2f}')
# plt.length()
plt.show()

#Print prediction for 2020
print(f"The predicted per capita income for the year 2020 is: ${predicted_Val[0][0]:.2f}")
# Out:
# The predicted per capita income for the year 2020 is: $41288.69
